# %% [markdown]
# <a href="https://colab.research.google.com/github/taherezzaier/Projet/blob/main/HeartDisease.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_csv('/content/heart.csv')

data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Activité 1:
# Explorez le dataset : taille, informations sur les variables indépendantes et les variables dépendantes
# Effectuez une AED

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
print ("les dimension de dataset sont (nombre de ligne nombre de colonne)=",data.shape)
# Out:
# les dimension de dataset sont (nombre de ligne nombre de colonne)= (303, 14)

# %%
data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %% [markdown]
# # ***Analyse univarie***

# %%
data['target'].value_counts(normalize=True).plot.bar(title="target")
# Out:
# <Axes: title={'center': 'target'}, xlabel='target'>

# %%
data['age'].value_counts(normalize=True).plot.bar(title="age")
# Out:
# <Axes: title={'center': 'age'}, xlabel='age'>

# %%
data['sex'].value_counts(normalize=True).plot.bar(title="sex")
# Out:
# <Axes: title={'center': 'sex'}, xlabel='sex'>

# %%
data['cp'].value_counts(normalize=True).plot.bar(title="cp")
# Out:
# <Axes: title={'center': 'cp'}, xlabel='cp'>

# %%
data['trestbps'].value_counts(normalize=True).plot.bar(title="trestbps")
# Out:
# <Axes: title={'center': 'trestbps'}, xlabel='trestbps'>

# %%
data['chol'].value_counts(normalize=True).plot.bar(title="chol")
# Out:
# <Axes: title={'center': 'chol'}, xlabel='chol'>

# %%
data['fbs'].value_counts(normalize=True).plot.bar(title="fbs")
# Out:
# <Axes: title={'center': 'fbs'}, xlabel='fbs'>

# %%
data['restecg'].value_counts(normalize=True).plot.bar(title="restecg")
# Out:
# <Axes: title={'center': 'restecg'}, xlabel='restecg'>

# %%
data['thalach'].value_counts(normalize=True).plot.bar(title="thalach")
# Out:
# <Axes: title={'center': 'thalach'}, xlabel='thalach'>

# %%
data['exang'].value_counts(normalize=True).plot.bar(title="exang")
# Out:
# <Axes: title={'center': 'exang'}, xlabel='exang'>

# %%
data['oldpeak'].value_counts(normalize=True).plot.bar(title="oldpeak")
# Out:
# <Axes: title={'center': 'oldpeak'}, xlabel='oldpeak'>

# %%
data['slope'].value_counts(normalize=True).plot.bar(title="slope")
# Out:
# <Axes: title={'center': 'slope'}, xlabel='slope'>

# %%
data['ca'].value_counts(normalize=True).plot.bar(title="ca")
# Out:
# <Axes: title={'center': 'ca'}, xlabel='ca'>

# %%
data['thal'].value_counts(normalize=True).plot.bar(title="thal")
# Out:
# <Axes: title={'center': 'thal'}, xlabel='thal'>

# %% [markdown]
# # ***Analyse bivarié par rapport à la variable cible***

# %%
# !pip install seaborn # Install seaborn library
import seaborn as sns # Import the library and assign it the alias 'sns'

# %%
sns.countplot(x='age', hue='target', data=data, linewidth=5);

# %%
sns.countplot(x='sex', hue='target', data=data, linewidth=5);

# %%
sns.countplot(x='cp', hue='target', data=data, linewidth=5);

# %%
sns.countplot(x='trestbps', hue='target', data=data, linewidth=5);

# %%
sns.countplot(x='chol', hue='target', data=data, linewidth=5);

# %%
sns.countplot(x='fbs', hue='target', data=data, linewidth=5);

# %%
sns.countplot(x='restecg', hue='target', data=data, linewidth=5);

# %%
sns.countplot(x='thalach', hue='target', data=data, linewidth=5);

# %%
sns.countplot(x='exang', hue='target', data=data, linewidth=5);

# %%
sns.countplot(x='oldpeak', hue='target', data=data, linewidth=5);

# %%
sns.countplot(x='slope', hue='target', data=data, linewidth=5);

# %%
sns.countplot(x='ca', hue='target', data=data, linewidth=5);

# %%
sns.countplot(x='thal', hue='target', data=data, linewidth=5);

# %%
sns.pairplot(data, hue="target",diag_kind="hist" )

# %%
matrix = data.corr()
sns.heatmap(matrix, vmax=.8, square=True, cmap="coolwarm",annot=True,linewidths=.5);

# %%
# Importer le module matplotlib.pyplot
import matplotlib.pyplot as plt

# %%
# Créer un tracé de matrice de dispersion
sns.pairplot(data, diag_kind='kde', hue='target')
plt.suptitle("Matrice de dispersion avec KDE")
plt.show()

# %% [markdown]
# Dans un second temps, on effectue un prétraitement des données on supprime les données manquantes si on les trouves.

# %%
data.isnull().sum()

# %% [markdown]
# on regarde la distribution des labels

# %%
y=data['target'] #Labels
x=data.drop('target',axis=1) #Features

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x= 'target', data= data)
plt.xticks([0,1],['Non','Oui'])
plt.title('Répartitions des Labels')

# %% [markdown]
# On voit que on a des données "oui" (le cas où une personne à etait detecté par une maladie du coeur ) et "non" (le cas où une personne n'as pas etait detecté par une maladie du coeur ). Sela ne  Nécessité pas un  réechantillonage puisque les données concernent la varible explicative sont trés proche .
# Maintenant séparons les données en train_set et test_set.

# %% [markdown]
# Maintenant séparons les données en train_set et test_set.

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split (x,y,test_size=0.2)

# %%
from sklearn.linear_model import Perceptron

ppn = Perceptron(max_iter=40,tol=0.001,eta0=1)  #eta0 est le learning rate c'est epsilon
#tol est le seuil minimum de stopping criteria si (tol +loss) > prevloss exit : on ne permet pas que loss grandit plus que le seuil tol
#score Return the mean accuracy on the given test data and labels.
ppn.fit(x_train, y_train)

y_pred = ppn.predict(x_test)
score = ppn.score(x_test,y_test)
print(score)

# %%
print ("évaluation du Perceptron")
from sklearn.metrics import classification_report
print (classification_report(y_test, y_pred))

# %% [markdown]
# Selon l'évaluation du Perceptron on peut remarque que le taux de precision pour "oui" "1" (le cas où une personne à etait detecté par une maladie du coeur )  representer 0.56 soit 56%
# Par contre le taux de precision pour "non" "0" (le cas où une personne n'etait pas detecté par une maladie du coeur )
# representer 0.85 soit 85% qui represente un bon resultat

# %%
import tensorflow as tf

nn=tf.keras.Sequential() #On crée notre architecture

nn.add(tf.keras.layers.Dense(units=8, activation='relu')) #On ajoute une couche de 8 neurones cachés

nn.add(tf.keras.layers.Dense(units=5, activation='relu')) #On ajoute une couche de 5 neurones cachés

nn.add(tf.keras.layers.Dense(units=2, activation='relu')) #On ajoute une couche de 2 neurones cachés

nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid')) #Couche de sortie

nn.compile('adam','binary_crossentropy',metrics=['accuracy'])
#On crée le modèle avec les paramètres comme la fonctions de perte ou la métrique utilisées... .

# %%
nn.fit(x_train,y_train,epochs=3,batch_size=1,verbose=1) #On entraine notre modèle verboze permet d'afficher le détail des epochs

# %%
#Pour les résultats sur le test set
y_pred=nn.predict(x_test)
y_pred

# %%
from sklearn.metrics import confusion_matrix
MonTableau_bin_y_pred=[]
for i in nn.predict(x_test):
    if i>0.5:
        MonTableau_bin_y_pred.append(1)
    if i<0.5:
        MonTableau_bin_y_pred.append(0)

print("Matrice de confusion : \n",confusion_matrix(y_test,MonTableau_bin_y_pred))

from sklearn.metrics import accuracy_score
print("Accuracy de notre réseau de neurone est : ",accuracy_score(y_test,MonTableau_bin_y_pred))
